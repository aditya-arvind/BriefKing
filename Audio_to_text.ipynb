# %%
# # importing libraries 
# import speech_recognition as sr 
# import os 
# from pydub import AudioSegment
# from pydub.silence import split_on_silence


# # create a speech recognition object
# r = sr.Recognizer()
# path="C:\\Users\\Acer\\Desktop\\Mtech Project Topic\\Kaggle\\my_hot_milf"
# print("hihihihihi")

#     # process each chunk 
#     for i, audio_chunk in enumerate(chunks, start=1):
#         # export audio chunk and save it in
#         # the `folder_name` directory.
#         chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
#         audio_chunk.export(chunk_filename, format="wav")
#         # recognize the chunk
#         with sr.AudioFile(chunk_filename) as source:
#             audio_listened = r.record(source)
#             # try converting it to text
#             try:
#                 text = r.recognize_google(audio_listened)
#             except sr.UnknownValueError as e:
#                 print("Error:", str(e))
#             else:
#                 text = f"{text.capitalize()}. "

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

# %%
path="C:\\Users\\Acer\\Desktop\\Mtech Project Topic\\Kaggle\\SC607-L4.wav"
get_large_audio_transcription(path)
# Out:
# Error:
# audio-chunks\chunk2.wav : I will begin with the earth.
# audio-chunks\chunk3.wav : Study of first class of optimization problems which is.
# audio-chunks\chunk4.wav : Optimisation.
# Error:
# audio-chunks\chunk6.wav : A function.
# audio-chunks\chunk7.wav : Over.
# audio-chunks\chunk8.wav : An open set.
# audio-chunks\chunk9.wav : So.
# audio-chunks\chunk10.wav : What this means is that the.
# audio-chunks\chunk11.wav : Feasible region.
# audio-chunks\chunk12.wav : Open sex.
# audio-chunks\chunk13.wav : And.
# audio-chunks\chunk14.wav : Function.
# audio-chunks\chunk15.wav : Aur.
# audio-chunks\chunk16.wav : Photo function.
# audio-chunks\chunk17.wav : Kylie.
# audio-chunks\chunk18.wav : Jaipur.
# audio-chunks\chunk19.wav : Function.
# audio-chunks\chunk20.wav : You love you know this to be.
# audio-chunks\chunk21.wav : Differentiable function.
# audio-chunks\chunk22.wav : Now.
# audio-chunks\chunk23.wav : Going to talk about differentiable functions i need to tell you a little bit about.
# audio-chunks\chunk24.wav : Bhai notation for derivatives second derivatives install.
# Error:
# audio-chunks\chunk26.wav : Let s be a function.
# audio-chunks\chunk27.wav : From.
# audio-chunks\chunk28.wav : R and 2r.
# Error:
# audio-chunks\chunk30.wav : Nxn aryan.
# audio-chunks\chunk31.wav : I will write it.
# audio-chunks\chunk32.wav : I will be not it in the sort of way.
# audio-chunks\chunk33.wav : Co-ordinate size.
# audio-chunks\chunk34.wav : This is the.
# audio-chunks\chunk35.wav : Every vector x narayan this we will be referring to fitted as a column vector.
# audio-chunks\chunk36.wav : Now.
# audio-chunks\chunk37.wav : When i write something like s x.
# audio-chunks\chunk38.wav : Valuated at exide.
# audio-chunks\chunk39.wav : What this means is this is me.
# audio-chunks\chunk40.wav : Derivative.
# audio-chunks\chunk41.wav : Office.
# audio-chunks\chunk42.wav : At.
# audio-chunks\chunk43.wav : Exact.
# audio-chunks\chunk44.wav : Smallest year.
# audio-chunks\chunk45.wav : Smallest in this notation this simply said that.
# audio-chunks\chunk46.wav : Derivative with respect to x.
# audio-chunks\chunk47.wav : Bittu.
# audio-chunks\chunk48.wav : This should be important when we are talking about.
# audio-chunks\chunk49.wav : Functions that are functions of more than one way.
# audio-chunks\chunk50.wav : We may want to take derivative only with recipe.
# audio-chunks\chunk51.wav : Derivative.
# Error:
# audio-chunks\chunk53.wav : Another notation for the same thing.
# audio-chunks\chunk54.wav : Is.
# audio-chunks\chunk55.wav : Value added tax.
# audio-chunks\chunk56.wav : Aur.
# audio-chunks\chunk57.wav : Important thing to note is that this.
# audio-chunks\chunk58.wav : This quantity app.
# Error:
# audio-chunks\chunk60.wav : Xx.
# audio-chunks\chunk61.wav : This is actually a role actor.
# audio-chunks\chunk62.wav : Google.
# audio-chunks\chunk63.wav : It is defined in this way you can consider the partial derivatives.
# audio-chunks\chunk64.wav : With respect to each of the components of x.
# audio-chunks\chunk65.wav : Daman to erode.
# audio-chunks\chunk66.wav : Evaluate all of these attic.
# audio-chunks\chunk67.wav : Sof subex evaluated at expert is this row vector.
# audio-chunks\chunk68.wav : There is a related quantity.
# audio-chunks\chunk69.wav : Denoted in this sort of way.
# audio-chunks\chunk70.wav : Aur.
# audio-chunks\chunk71.wav : To be more explicit about.
# audio-chunks\chunk72.wav : What's your differentiating with.
# audio-chunks\chunk73.wav : This way and that is simply.
# audio-chunks\chunk74.wav : The transpose of this perimeter.
# audio-chunks\chunk75.wav : This thing is called.
# audio-chunks\chunk76.wav : The gradient.
# audio-chunks\chunk77.wav : Offer.
# audio-chunks\chunk78.wav : Attack.
# audio-chunks\chunk79.wav : Once again the.
# Error:
# audio-chunks\chunk81.wav : Small express.
# audio-chunks\chunk82.wav : Simply do not.
# audio-chunks\chunk83.wav : That.
# audio-chunks\chunk84.wav : Gradient with respect to the variable.
# Error:
# audio-chunks\chunk86.wav : Propose.
# audio-chunks\chunk87.wav : You have a function f which is.
# audio-chunks\chunk88.wav : Function from.
# audio-chunks\chunk89.wav : Aryan.
# audio-chunks\chunk90.wav : Cross rm.
# audio-chunks\chunk91.wav : You are.
# audio-chunks\chunk92.wav : My very well.
# audio-chunks\chunk93.wav : Bi variable x.
# Error:
# audio-chunks\chunk95.wav : X variable live.
# Error:
# audio-chunks\chunk97.wav : Aryan.
# audio-chunks\chunk98.wav : Why variable is in array.
# audio-chunks\chunk99.wav : Dainik bhai write something like this f sub x.
# audio-chunks\chunk100.wav : Write something like this left cervix.
# audio-chunks\chunk101.wav : At.
# audio-chunks\chunk102.wav : White korma white.
# audio-chunks\chunk103.wav : This year.
# Error:
# audio-chunks\chunk105.wav : In this row vector or column vector.
# audio-chunks\chunk106.wav : It is a robot.
# audio-chunks\chunk107.wav : Ok.
# audio-chunks\chunk108.wav : Abhi to how many components.
# audio-chunks\chunk109.wav : And company.
# audio-chunks\chunk110.wav : Because that is the number of component and taking the derivative with.
# audio-chunks\chunk111.wav : Accident.
# audio-chunks\chunk112.wav : Zero vector.
# audio-chunks\chunk113.wav : Also denoted by.
# audio-chunks\chunk114.wav : Now if.
# audio-chunks\chunk115.wav : F is.
# audio-chunks\chunk116.wav : Both of these cases here in this case as well as in.
# audio-chunks\chunk117.wav : Dalia case.
# audio-chunks\chunk118.wav : Go to biscuits.
# audio-chunks\chunk119.wav : F was a function that map to our.
# audio-chunks\chunk120.wav : The sof.
# audio-chunks\chunk121.wav : Itself did not have.
# audio-chunks\chunk122.wav : Multiple.
# audio-chunks\chunk123.wav : Rajasv incomp.
# audio-chunks\chunk124.wav : F is a scalar valued.
# audio-chunks\chunk125.wav : Wooden now if f is better value.
# audio-chunks\chunk126.wav : Write the square.
# Error:
# audio-chunks\chunk128.wav : Inner value.
# audio-chunks\chunk129.wav : S.
# audio-chunks\chunk130.wav : A vector valued function then say we have.
# audio-chunks\chunk131.wav : Suppose f is a function from r in.
# audio-chunks\chunk132.wav : Rustom rm.
# audio-chunks\chunk133.wav : And.
# audio-chunks\chunk134.wav : What we will do if we will think of this.
# audio-chunks\chunk135.wav : Every.
# audio-chunks\chunk136.wav : Output of this vector.
# audio-chunks\chunk137.wav : Every point in the.
# audio-chunks\chunk138.wav : Image of this of f is itself a vector.
# audio-chunks\chunk139.wav : Call ambedkar.
# audio-chunks\chunk140.wav : F.
# audio-chunks\chunk141.wav : Be part of like this if.
# audio-chunks\chunk142.wav : Atta point.
# audio-chunks\chunk143.wav : X.
# audio-chunks\chunk144.wav : Is equal to.
# audio-chunks\chunk145.wav : This kind of column vector.
# audio-chunks\chunk146.wav : F1 of x.
# audio-chunks\chunk147.wav : F2 effect.
# audio-chunks\chunk148.wav : Gov.in.
# audio-chunks\chunk149.wav : I'm calling.
# audio-chunks\chunk150.wav : If i want to do if i take the derivative of x with respect to x.
# audio-chunks\chunk151.wav : What i need to do is.
# audio-chunks\chunk152.wav : 1 the derivative of each of these component.
# Error:
# audio-chunks\chunk154.wav : This.
# audio-chunks\chunk155.wav : Evaluated at.
# audio-chunks\chunk156.wav : Now become.
# audio-chunks\chunk157.wav : Every row.
# audio-chunks\chunk158.wav : Every every component of f.
# audio-chunks\chunk159.wav : Will have a derivative and will its derivative would be a row vector like this.
# audio-chunks\chunk160.wav : And what you are going to get now is row vector stop that one below the other so the.
# audio-chunks\chunk161.wav : Pradesh.
# audio-chunks\chunk162.wav : Ko dikhao.
# audio-chunks\chunk163.wav : So that's your.
# audio-chunks\chunk164.wav : This is also good.
# Error:
# audio-chunks\chunk166.wav : Multiple name for this.
# audio-chunks\chunk167.wav : Simple.
# audio-chunks\chunk168.wav : Call derivative.
# audio-chunks\chunk169.wav : Aap f.
# audio-chunks\chunk170.wav : At at.
# Error:
# audio-chunks\chunk172.wav : Other name for it is that it.
# audio-chunks\chunk173.wav : Alter jacobian.
# audio-chunks\chunk174.wav : Ok.
# audio-chunks\chunk175.wav : Hi tech.
# audio-chunks\chunk176.wav : How we can also write hai.
# audio-chunks\chunk177.wav : Another higher order derivative.
# audio-chunks\chunk178.wav : What's called.
# audio-chunks\chunk179.wav : Asian.
# audio-chunks\chunk180.wav : Asian is simply.
# Error:
# audio-chunks\chunk182.wav : Profile pic.
# audio-chunks\chunk183.wav : Of the derivative.
# audio-chunks\chunk184.wav : But the derivative of the day.
# audio-chunks\chunk185.wav : I need to take.
# audio-chunks\chunk186.wav : I am taking the derivative of the derivative.
# audio-chunks\chunk187.wav : Nothing.
# Error:
# audio-chunks\chunk189.wav : Select.
# audio-chunks\chunk190.wav : I am taking the derivative.
# audio-chunks\chunk191.wav : Of the gradient.
# audio-chunks\chunk192.wav : Evaluating that.
# audio-chunks\chunk193.wav : This.
# Error:
# audio-chunks\chunk195.wav : Another term for the same.
# audio-chunks\chunk196.wav : Another way of writing the same thing.
# audio-chunks\chunk197.wav : This again.
# audio-chunks\chunk198.wav : Because the gradient is a column vector.
# Error:
# audio-chunks\chunk200.wav : Pick the derivative of that.
# audio-chunks\chunk201.wav : Anda.
# audio-chunks\chunk202.wav : Then we'll go.
# Error:
# audio-chunks\chunk204.wav : Agnimitra.
# audio-chunks\chunk205.wav : Matrix that look.
# audio-chunks\chunk206.wav : Aur didi valuated natak.
# audio-chunks\chunk207.wav : Another notation for the same thing is simply.
# audio-chunks\chunk208.wav : Dell square.
# audio-chunks\chunk209.wav : Evaluated.
# Error:
# Error:
# audio-chunks\chunk212.wav : Along with derivatives you also need.
# audio-chunks\chunk213.wav : Important.
# audio-chunks\chunk214.wav : Advertence to derivatives.
# audio-chunks\chunk215.wav : Derivatives of different derivatives and approximations of.
# Error:
# audio-chunks\chunk217.wav : Rishte ram.
# audio-chunks\chunk218.wav : Could be known to you in some of the other form probably before this.
# audio-chunks\chunk219.wav : This is.
# Error:
# audio-chunks\chunk221.wav : Basically said that if you have a differentiable function.
# Error:
# audio-chunks\chunk223.wav : The value of the function.
# audio-chunks\chunk224.wav : Close.
# audio-chunks\chunk225.wav : Reference point.
# Error:
# audio-chunks\chunk227.wav : Value of a function very close to that reference.
# audio-chunks\chunk228.wav : What taylor's theorem is basically saying.
# audio-chunks\chunk229.wav : Is.
# audio-chunks\chunk230.wav : Diet.
# audio-chunks\chunk231.wav : Close to that reference point.
# audio-chunks\chunk232.wav : Value of the function.
# audio-chunks\chunk233.wav : Is.
# audio-chunks\chunk234.wav : Very well approximated.
# audio-chunks\chunk235.wav : Bye.
# audio-chunks\chunk236.wav : Linear function.
# audio-chunks\chunk237.wav : That you can construct during the value of the function at the point and the derivative of the.
# audio-chunks\chunk238.wav : What does it mean by well approximated.
# audio-chunks\chunk239.wav : What is the centre of the earth.
# audio-chunks\chunk240.wav : That is the party what is made precise by.
# Error:
# audio-chunks\chunk242.wav : But the main idea is basically that.
# audio-chunks\chunk243.wav : When you are close if your function is differentiable.
# Error:
# audio-chunks\chunk245.wav : And you want to look at what how the function behaves near a point.
# audio-chunks\chunk246.wav : Some reference point want to know.
# audio-chunks\chunk247.wav : Well near it out.
# Error:
# audio-chunks\chunk249.wav : Tell you that.
# audio-chunks\chunk250.wav : Alina.
# audio-chunks\chunk251.wav : Approximation.
# audio-chunks\chunk252.wav : Can you open.
# audio-chunks\chunk253.wav : Gallery vault backup.
# audio-chunks\chunk254.wav : Kalyan.
# audio-chunks\chunk255.wav : Very precise.
# audio-chunks\chunk256.wav : So.
# Error:
# audio-chunks\chunk258.wav : Calling.
# audio-chunks\chunk259.wav : Let.
# audio-chunks\chunk260.wav : F form.
# audio-chunks\chunk261.wav : Current war.
# audio-chunks\chunk262.wav : B.ed principal.
# audio-chunks\chunk263.wav : Let a be a point in array.
# audio-chunks\chunk264.wav : This is my reference point.
# Error:
# audio-chunks\chunk266.wav : American.
# audio-chunks\chunk267.wav : What i want to know is how does the function behave.
# audio-chunks\chunk268.wav : At another point.
# audio-chunks\chunk269.wav : Dengudu.
# audio-chunks\chunk270.wav : Lyrics.
# Error:
# audio-chunks\chunk272.wav : Start of function age.
# audio-chunks\chunk273.wav : Such that.
# audio-chunks\chunk274.wav : You take.
# audio-chunks\chunk275.wav : Peppa pig.
# audio-chunks\chunk276.wav : Then that's value of the function at x that other point x.
# audio-chunks\chunk277.wav : Is given by the.
# audio-chunks\chunk278.wav : Even as a pop a.
# Error:
# Error:
# audio-chunks\chunk281.wav : Ok.
# audio-chunks\chunk282.wav : In my location i want to.
# audio-chunks\chunk283.wav : Abusing.
# audio-chunks\chunk284.wav : During this bikes let me do not this bye.
# audio-chunks\chunk285.wav : Huawei.
# audio-chunks\chunk286.wav : You know my reference point is a and my point at which i want to evaluate the functional is called that why.
# audio-chunks\chunk287.wav : F y is equal to f.
# audio-chunks\chunk288.wav : Love.
# audio-chunks\chunk289.wav : What is this vector now this is a row vector.
# audio-chunks\chunk290.wav : Which is the derivative of s.
# audio-chunks\chunk291.wav : With respect to 1.
# audio-chunks\chunk292.wav : Evaluated at.
# audio-chunks\chunk293.wav : Sudha transport.
# audio-chunks\chunk294.wav : Why minus.
# audio-chunks\chunk295.wav : Love.
# Error:
# audio-chunks\chunk297.wav : Function.
# audio-chunks\chunk298.wav : Age of vi.
# audio-chunks\chunk299.wav : X minus.
# audio-chunks\chunk300.wav : Where.
# audio-chunks\chunk301.wav : This is important part.
# audio-chunks\chunk302.wav : With h.
# audio-chunks\chunk303.wav : Fb.
# audio-chunks\chunk304.wav : Tends to zero.
# audio-chunks\chunk305.wav : As.
# audio-chunks\chunk306.wav : White.
# audio-chunks\chunk307.wav : Ok.
# Error:
# audio-chunks\chunk309.wav : Now i want to appreciate what this order what this theorem is actually saying.
# audio-chunks\chunk310.wav : President as we go into the next hour main result also.
# audio-chunks\chunk311.wav : But.
# audio-chunks\chunk312.wav : Remember.
# audio-chunks\chunk313.wav : I just this for.
# audio-chunks\chunk314.wav : Clarity le i want to do.
# audio-chunks\chunk315.wav : What does a.
# audio-chunks\chunk316.wav : Aaj y tends to a of course it is true that.
# audio-chunks\chunk317.wav : Ok bye.
# audio-chunks\chunk318.wav : And if of a will come close with.
# audio-chunks\chunk319.wav : Aaj vi 10th a.
# audio-chunks\chunk320.wav : 45 in a brochure for free.
# audio-chunks\chunk321.wav : But that is not saying anything.
# audio-chunks\chunk322.wav : What this theorem is saying is.
# audio-chunks\chunk323.wav : That is white and 2a.
# audio-chunks\chunk324.wav : Locate app of y minus frp.
# audio-chunks\chunk325.wav : Iphone 5 - 1 copy.
# audio-chunks\chunk326.wav : Divide the whole thing by y minus a.
# Error:
# audio-chunks\chunk328.wav : Start behaving more and more like.
# audio-chunks\chunk329.wav : Effects of.
# audio-chunks\chunk330.wav : What this theorem is effective listening.
# audio-chunks\chunk331.wav : Is that.
# Error:
# audio-chunks\chunk333.wav : Look at the.
# audio-chunks\chunk334.wav : Of course true that.
# audio-chunks\chunk335.wav : Is white and 2a.
# audio-chunks\chunk336.wav : X tends to a type of white and swift of a.
# audio-chunks\chunk337.wav : What we say i am telling you is how fast does white and.
# audio-chunks\chunk338.wav : Gazette of white n2f4.
# audio-chunks\chunk339.wav : Acquaintance.
# audio-chunks\chunk340.wav : What this is a gadget telling you.
# audio-chunks\chunk341.wav : Can you somehow.
# audio-chunks\chunk342.wav : Images on.
# audio-chunks\chunk343.wav : This different.
# audio-chunks\chunk344.wav : Telling you that this difference.
# audio-chunks\chunk345.wav : Map of y minus of a.
# audio-chunks\chunk346.wav : / -.
# audio-chunks\chunk347.wav : This.
# audio-chunks\chunk348.wav : Is.
# audio-chunks\chunk349.wav : Something.
# audio-chunks\chunk350.wav : Is equal to effect.
# audio-chunks\chunk351.wav : Ok.
# audio-chunks\chunk352.wav : Sketch of vi.
# audio-chunks\chunk353.wav : With each of y is a quantity that will become smaller and smaller.
# audio-chunks\chunk354.wav : This will become small.
# audio-chunks\chunk355.wav : As white ants.
# audio-chunks\chunk356.wav : Become close to zero as white.
# audio-chunks\chunk357.wav : Mukesh.
# audio-chunks\chunk358.wav : What vitamins actually effect.
# audio-chunks\chunk359.wav : Telling you.
# audio-chunks\chunk360.wav : It is not only telling you that.
# audio-chunks\chunk361.wav : The function values near.
# audio-chunks\chunk362.wav : 8 lost 2fa.
# audio-chunks\chunk363.wav : But we already know.
# audio-chunks\chunk364.wav : It is also tell you how fast the approaches copy.
# audio-chunks\chunk365.wav : Ok launcher coffee at a rate.
# audio-chunks\chunk366.wav : That is.
# audio-chunks\chunk367.wav : Linear in y minus.
# audio-chunks\chunk368.wav : And the constant of linearity there.
# Error:
# audio-chunks\chunk370.wav : Roughly equal to effects of a.
# audio-chunks\chunk371.wav : Effects of a plus this age of why my right of why become smaller and smaller as you go.
# audio-chunks\chunk372.wav : All optimization is about this.
# audio-chunks\chunk373.wav : About fast.
# audio-chunks\chunk374.wav : Different quantities convert.
# audio-chunks\chunk375.wav : Read the relative rates at with different quantities converges.
# audio-chunks\chunk376.wav : Computer.
# audio-chunks\chunk377.wav : Eating all the time in ok.
# audio-chunks\chunk378.wav : That is why.
# audio-chunks\chunk379.wav : An estimate like the like this one which come from taylor's theorem.
# Error:
# Error:
# audio-chunks\chunk382.wav : Enna sona.
# Error:
# audio-chunks\chunk384.wav : Now let's go forward and actually.
# audio-chunks\chunk385.wav : Sexy how this.
# Error:
# audio-chunks\chunk387.wav : Postman download.
# audio-chunks\chunk388.wav : So.
# audio-chunks\chunk389.wav : Now i want to talk about.
# audio-chunks\chunk390.wav : Go back to work.
# audio-chunks\chunk391.wav : Topic started messages that you want to.
# audio-chunks\chunk392.wav : Optimisation of a function over.
# audio-chunks\chunk393.wav : Open set.
# audio-chunks\chunk394.wav : Kishor.
# audio-chunks\chunk395.wav : I want to talk of minimum minimising a function f.
# audio-chunks\chunk396.wav : Oversight.
# audio-chunks\chunk397.wav : Sofa set.
# audio-chunks\chunk398.wav : Feasible region.
# audio-chunks\chunk399.wav : Feasible region.
# Error:
# audio-chunks\chunk401.wav : This isn't some open.
# audio-chunks\chunk402.wav : Assume that f is different.
# audio-chunks\chunk403.wav : Right.
# audio-chunks\chunk404.wav : The theorem.
# audio-chunks\chunk405.wav : Net.
# Error:
# Error:
# audio-chunks\chunk408.wav : B.
# audio-chunks\chunk409.wav : Inoperable.
# audio-chunks\chunk410.wav : Solution.
# Error:
# audio-chunks\chunk412.wav : Optimisation problem.
# audio-chunks\chunk413.wav : Minimum.
# audio-chunks\chunk414.wav : Minimise.
# audio-chunks\chunk415.wav : Function f.
# audio-chunks\chunk416.wav : Subject.
# audio-chunks\chunk417.wav : Let f.
# audio-chunks\chunk418.wav : Video constable.
# audio-chunks\chunk419.wav : And let.
# Error:
# Error:
# audio-chunks\chunk422.wav : Bewafa.
# audio-chunks\chunk423.wav : Then we must have.
# audio-chunks\chunk424.wav : Look at me.
# audio-chunks\chunk425.wav : Derivative of f at.
# audio-chunks\chunk426.wav : With respect to x evaluated at x.
# audio-chunks\chunk427.wav : Value added tax.
# audio-chunks\chunk428.wav : Hindi derivative masti.
# audio-chunks\chunk429.wav : What is the current.
# audio-chunks\chunk430.wav : Remix sorry understand what.
# audio-chunks\chunk431.wav : What this.
# audio-chunks\chunk432.wav : Sing that.
# audio-chunks\chunk433.wav : Consider consider this optimization problem.
# audio-chunks\chunk434.wav : Suppose there is an optimal solution.
# audio-chunks\chunk435.wav : It is not saying there is enough.
# audio-chunks\chunk436.wav : Singh suppose the return of rebel.
# audio-chunks\chunk437.wav : And.
# audio-chunks\chunk438.wav : Documentation problem has the feature has the properties that f is differentiable.
# audio-chunks\chunk439.wav : And the feasible region is a open set.
# audio-chunks\chunk440.wav : Then it has to be that.
# audio-chunks\chunk441.wav : The derivative.
# Error:
# audio-chunks\chunk443.wav : Of the function with respect to x.
# audio-chunks\chunk444.wav : Evaluated at axa.
# audio-chunks\chunk445.wav : Chunav latest let's prove this.
# Error:
# audio-chunks\chunk447.wav : Akshara licinius.
# audio-chunks\chunk448.wav : And.
# audio-chunks\chunk449.wav : S is open.
# audio-chunks\chunk450.wav : What do we know.
# audio-chunks\chunk451.wav : Effector is a point anus.
# audio-chunks\chunk452.wav : Set s gopan.
# audio-chunks\chunk453.wav : What must be the case.
# audio-chunks\chunk454.wav : When there is a ball around around extra that lies completely in a.
# Error:
# Error:
# audio-chunks\chunk457.wav : Picture if you have in mind is to suppose imagine this is your sad s.
# audio-chunks\chunk458.wav : This is your point.
# Error:
# audio-chunks\chunk460.wav : There is a ball around it like this.
# audio-chunks\chunk461.wav : That lies completely.
# audio-chunks\chunk462.wav : What that means.
# audio-chunks\chunk463.wav : Bed exercise.
# audio-chunks\chunk464.wav : Radius are greater than zero.
# audio-chunks\chunk465.wav : 5000000.
# audio-chunks\chunk466.wav : X belongs s.
# audio-chunks\chunk467.wav : Whenever.
# audio-chunks\chunk468.wav : Distance between x and xr.
# audio-chunks\chunk469.wav : National.
# Error:
# audio-chunks\chunk471.wav : What is unique about.
# audio-chunks\chunk472.wav : About the ball.
# audio-chunks\chunk473.wav : What is so interesting about the ok there is a ball around the point x serve it lies completely in.
# audio-chunks\chunk474.wav : So what what if there is a bond.
# audio-chunks\chunk475.wav : What is what so great about.
# audio-chunks\chunk476.wav : About the ball.
# audio-chunks\chunk477.wav : The many interesting things about the ball but i think that.
# Error:
# audio-chunks\chunk479.wav : Use of elements.
# audio-chunks\chunk480.wav : Is that remember the unit any born.
# audio-chunks\chunk481.wav : Ok of unit ball or any a ball of any radio.
# audio-chunks\chunk482.wav : Positive radio.
# audio-chunks\chunk483.wav : Insulin like all of orange trunk.
# audio-chunks\chunk484.wav : Download.
# audio-chunks\chunk485.wav : Download small adele.
# audio-chunks\chunk486.wav : What does mean this.
# audio-chunks\chunk487.wav : If you.
# audio-chunks\chunk488.wav : Look ad.
# audio-chunks\chunk489.wav : Extra.
# audio-chunks\chunk490.wav : Are you look at any other point in array.
# audio-chunks\chunk491.wav : Get the direction starting from extra going towards that other phone.
# audio-chunks\chunk492.wav : All the other point.
# audio-chunks\chunk493.wav : Look at this direction that starts from extra going.
# audio-chunks\chunk494.wav : Going towards.
# audio-chunks\chunk495.wav : Get direction.
# audio-chunks\chunk496.wav : Ok this is a real that starts.
# audio-chunks\chunk497.wav : Go to advice.
# audio-chunks\chunk498.wav : What i can do it without changing the direction.
# audio-chunks\chunk499.wav : I can simply drink this re all the way down to the point where.
# audio-chunks\chunk500.wav : Gaon battery.
# audio-chunks\chunk501.wav : Present completely in the ball.
# Error:
# audio-chunks\chunk503.wav : Any direction i can conceive of which is present.
# Error:
# audio-chunks\chunk505.wav : Setting for my words which i can go in aryan.
# audio-chunks\chunk506.wav : All of these directions are also present.
# audio-chunks\chunk507.wav : Inside the wallet.
# audio-chunks\chunk508.wav : Charge form from one form to word some point in the.
# audio-chunks\chunk509.wav : What that means.
# audio-chunks\chunk510.wav : Super every.
# audio-chunks\chunk511.wav : Vector.
# Error:
# audio-chunks\chunk513.wav : Narayan.
# audio-chunks\chunk514.wav : I can find.
# Error:
# audio-chunks\chunk516.wav : Geeta positive.
# audio-chunks\chunk517.wav : Such that.
# audio-chunks\chunk518.wav : Locate.
# audio-chunks\chunk519.wav : The best.
# audio-chunks\chunk520.wav : The vector x +.
# audio-chunks\chunk521.wav : Delta hai.
# audio-chunks\chunk522.wav : What does.
# audio-chunks\chunk523.wav : Is vector x + delta.
# audio-chunks\chunk524.wav : Belongs to.
# audio-chunks\chunk525.wav : Call delta.
# audio-chunks\chunk526.wav : Data.
# audio-chunks\chunk527.wav : Greater than equal to zero and less than equal to.
# audio-chunks\chunk528.wav : So.
# audio-chunks\chunk529.wav : Theek hai nahin direction.
# audio-chunks\chunk530.wav : Any direction.
# audio-chunks\chunk531.wav : What i can do is.
# audio-chunks\chunk532.wav : Take the direction and.
# audio-chunks\chunk533.wav : Kelly down by multiplying it.
# audio-chunks\chunk534.wav : The factor delta.
# audio-chunks\chunk535.wav : Such that now x + delta x that direction.
# audio-chunks\chunk536.wav : Zindabad.
# Error:
# Error:
# audio-chunks\chunk539.wav : This.
# audio-chunks\chunk540.wav : Lies in the bone and their for indians.
# Error:
# audio-chunks\chunk542.wav : Ok so every vector.
# audio-chunks\chunk543.wav : Director sarath are such that such that one field.
# Error:
# audio-chunks\chunk545.wav : Now.
# Error:
# audio-chunks\chunk547.wav : Vinod adhiktar is optimal.
# audio-chunks\chunk548.wav : An optimal solution.
# audio-chunks\chunk549.wav : What does that mean that mean the death of 1 star.
# audio-chunks\chunk550.wav : Is less than equal to.
# Error:
# audio-chunks\chunk552.wav : Rolex.
# audio-chunks\chunk553.wav : Birthday.
# audio-chunks\chunk554.wav : I can in particular take a point like this.
# audio-chunks\chunk555.wav : Baker point like.
# audio-chunks\chunk556.wav : Ekta + deltoid which is also live.
# audio-chunks\chunk557.wav : In particular.
# audio-chunks\chunk558.wav : Apothic star.
# audio-chunks\chunk559.wav : Is less than equal to f.
# audio-chunks\chunk560.wav : Extra + delta.
# audio-chunks\chunk561.wav : Whenever.
# audio-chunks\chunk562.wav : Now.
# audio-chunks\chunk563.wav : Remember.
# audio-chunks\chunk564.wav : The delta h and b is is the way you shri you what is the factor by which your shrunk the.
# Error:
# Error:
# audio-chunks\chunk567.wav : Chunav make delta smaller and smaller.
# audio-chunks\chunk568.wav : If data is smaller and smaller than an extra plus delta h is very close to extra it well.
# audio-chunks\chunk569.wav : Dandiya in the regime of.
# audio-chunks\chunk570.wav : Dussehra.
# audio-chunks\chunk571.wav : What does taylor theorem tell you.
# audio-chunks\chunk572.wav : Malleshwaram.
# audio-chunks\chunk573.wav : B f.
# audio-chunks\chunk574.wav : Taylor's theorem tell you that.
# audio-chunks\chunk575.wav : Map of x + delta h.
# audio-chunks\chunk576.wav : Equal to f of.
# Error:
# audio-chunks\chunk578.wav : Live.
# audio-chunks\chunk579.wav : Derivative of f.
# Error:
# audio-chunks\chunk581.wav : With respect to x evaluated at 1 star.
# audio-chunks\chunk582.wav : Time.
# audio-chunks\chunk583.wav : Times now extra minus.
# audio-chunks\chunk584.wav : 108 match delta h - extra so that's just delta.
# audio-chunks\chunk585.wav : Love something that was going to zero.
# audio-chunks\chunk586.wav : Ok now.
# audio-chunks\chunk587.wav : Go back to what kind of factory it was.
# audio-chunks\chunk588.wav : It was good to develop theorem said that there was.
# audio-chunks\chunk589.wav : Ok my slightly bad choice of foundation because they are there is this.
# audio-chunks\chunk590.wav : I've used it for the function.
# audio-chunks\chunk591.wav : Patakho ki will still be able to get.
# audio-chunks\chunk592.wav : Which factor.
# audio-chunks\chunk593.wav : Hair.
# audio-chunks\chunk594.wav : Sweater hair which was.
# Error:
# audio-chunks\chunk596.wav : Going to be row.
# audio-chunks\chunk597.wav : It is search type.
# audio-chunks\chunk598.wav : Itself goes to zero as y goes to zero.
# audio-chunks\chunk599.wav : Y minus a also goes to zero as y and y courses.
# audio-chunks\chunk600.wav : Because h goes to zero.
# audio-chunks\chunk601.wav : Aaj bhai ko 20 what this means is this.
# audio-chunks\chunk602.wav : Hd bat is love.
# audio-chunks\chunk603.wav : Is such that if i divide that by y minus a.
# audio-chunks\chunk604.wav : That also goes to the.
# audio-chunks\chunk605.wav : Best.
# audio-chunks\chunk606.wav : So.
# audio-chunks\chunk607.wav : Another way of writing taylor's theorem would be to say something like this.
# audio-chunks\chunk608.wav : Would be to say that this.
# audio-chunks\chunk609.wav : This star plus delta h is equal to effects.
# audio-chunks\chunk610.wav : Love this derivative x delta.
# Error:
# audio-chunks\chunk612.wav : Something which i will write like this.
# audio-chunks\chunk613.wav : Model of delta.
# audio-chunks\chunk614.wav : What is what do you mean by small of delta.
# audio-chunks\chunk615.wav : Value of delta i just the generic notation it stands for the following.
# audio-chunks\chunk616.wav : Mall of delta is.
# audio-chunks\chunk617.wav : Is there is any quantity.
# audio-chunks\chunk618.wav : Such that.
# audio-chunks\chunk619.wav : Quantity.
# audio-chunks\chunk620.wav : Safety data sheet of delta such that.
# audio-chunks\chunk621.wav : Pylokit.
# audio-chunks\chunk622.wav : Quantity.
# audio-chunks\chunk623.wav : Sexy doctor.
# audio-chunks\chunk624.wav : That.
# audio-chunks\chunk625.wav : Locate the limit.
# audio-chunks\chunk626.wav : Wallpaper download.
# audio-chunks\chunk627.wav : / delta.
# audio-chunks\chunk628.wav : Disco.
# audio-chunks\chunk629.wav : Ajay thakur.
# audio-chunks\chunk630.wav : So small of delta means that is approved not only does it itself go to zero.
# audio-chunks\chunk631.wav : Even after dividing by deltoid goes.
# Error:
# audio-chunks\chunk633.wav : So this is the way of writing things in optimisation we make this kind of shorthand we don't.
# audio-chunks\chunk634.wav : We don't really need to know what this exact thing is.
# audio-chunks\chunk635.wav : Long as we know.
# audio-chunks\chunk636.wav : At what weight it goes to.
# audio-chunks\chunk637.wav : Quantity can go to zero.
# audio-chunks\chunk638.wav : Badi.
# audio-chunks\chunk639.wav : But do.
# audio-chunks\chunk640.wav : Can you can have a quantity that.
# Error:
# audio-chunks\chunk642.wav : Seat of delta that goes to zero then.
# audio-chunks\chunk643.wav : Of delta / delta min.
# audio-chunks\chunk644.wav : But in this case this is a quantity of data itself was 20.
# audio-chunks\chunk645.wav : And upon dividing by delta also its one.
# audio-chunks\chunk646.wav : This should explore the significance of the.
# audio-chunks\chunk647.wav : What taylor theorem is basically telling us is that affect star plus delta is equal to fx star plus this derivative x x + this quantity.
# audio-chunks\chunk648.wav : Which is.
# Error:
# audio-chunks\chunk650.wav : This between this is something such that.
# audio-chunks\chunk651.wav : Mode of data / 20.
# audio-chunks\chunk652.wav : Asphalt 8.
# audio-chunks\chunk653.wav : Bole to.
# audio-chunks\chunk654.wav : If that is the case now what we get is.
# Error:
# audio-chunks\chunk656.wav : Now a perfect star.
# audio-chunks\chunk657.wav : Is.
# audio-chunks\chunk658.wav : Is.
# audio-chunks\chunk659.wav : Vinod the death of extra is less than equal to f of x +.
# audio-chunks\chunk660.wav : Iphone 7 plus khelta hai.
# audio-chunks\chunk661.wav : Consequently we get that.
# audio-chunks\chunk662.wav : Look at this difference fx star plus delta h - of extra that difference is greater than equal to zero.
# audio-chunks\chunk663.wav : Consequently i get that this is.
# audio-chunks\chunk664.wav : Now i can this holds for all.
# audio-chunks\chunk665.wav : Delta.
# audio-chunks\chunk666.wav : Gold for all delta.
# audio-chunks\chunk667.wav : Income neighborhoods zero to eta.
# audio-chunks\chunk668.wav : So what i can do it if.
# audio-chunks\chunk669.wav : Delta greater than zero.
# audio-chunks\chunk670.wav : That allows me to.
# audio-chunks\chunk671.wav : Device what by delta.
# audio-chunks\chunk672.wav : In that case i have that.
# audio-chunks\chunk673.wav : This is true.
# audio-chunks\chunk674.wav : This is true i can.
# audio-chunks\chunk675.wav : Now let.
# audio-chunks\chunk676.wav : Delta go 20.
# audio-chunks\chunk677.wav : Nagpur give me that.
# audio-chunks\chunk678.wav : The derivative.
# audio-chunks\chunk679.wav : Ff.
# audio-chunks\chunk680.wav : 2x valuator direct ka.
# audio-chunks\chunk681.wav : Time age.
# audio-chunks\chunk682.wav : Is greater than equal.
# audio-chunks\chunk683.wav : Remember this derivative is a row vector is a column vector is time this scalar is greater than equal.
# Error:
# audio-chunks\chunk685.wav : Now.
# audio-chunks\chunk686.wav : I can do this.
# audio-chunks\chunk687.wav : Ok so this is greater than equal to.
# audio-chunks\chunk688.wav : What did he want to show if you want to go back to the previous to the claim of the term it was saying that the derivative is equal to zero.
# audio-chunks\chunk689.wav : What i have got is that this in a product.
# audio-chunks\chunk690.wav : Bina product.
# audio-chunks\chunk691.wav : That is written here the derivative sign size.
# audio-chunks\chunk692.wav : This is guys if greater than equal to 0 for every vector day.
# audio-chunks\chunk693.wav : Every vector.
# audio-chunks\chunk694.wav : In general.
# audio-chunks\chunk695.wav : Because i started off with each other and arbitrary vector and i got that this thing should be greater than.
# audio-chunks\chunk696.wav : This has to be greater than equal to zero for every vector.
# audio-chunks\chunk697.wav : Ok what does that mean.
# audio-chunks\chunk698.wav : This must also be true for minus a.
# audio-chunks\chunk699.wav : Aur image be true in particular if i take h to be this get negative of this derivative itself.
# audio-chunks\chunk700.wav : So i can take for instance.
# audio-chunks\chunk701.wav : Hb.
# audio-chunks\chunk702.wav : Negative gradient of f.
# audio-chunks\chunk703.wav : That would then give me that my negative of.
# audio-chunks\chunk704.wav : Tere bete valuta natak star.
# audio-chunks\chunk705.wav : Norm of the whole thing square.
# audio-chunks\chunk706.wav : Greater than.
# audio-chunks\chunk707.wav : Chunav negative of the norm squared is greater than equal to zero that just mean that.
# audio-chunks\chunk708.wav : Norm of this derivative.
# audio-chunks\chunk709.wav : Where is less than equal to zero.
# audio-chunks\chunk710.wav : But it can't be strictly less than zero.
# audio-chunks\chunk711.wav : Which means it has to be equal to zero.
# audio-chunks\chunk712.wav : But when the norm is equal to zero means the vector itself.
# Error:
# audio-chunks\chunk714.wav : So that prove that.
# audio-chunks\chunk715.wav : So now understand the.
# Error:
# audio-chunks\chunk717.wav : Consequences of this.
# audio-chunks\chunk718.wav : And also understand what pic.
# audio-chunks\chunk719.wav : What limitations are.
# audio-chunks\chunk720.wav : The consequence mean consequences.
# audio-chunks\chunk721.wav : Remember.
# audio-chunks\chunk722.wav : That when you are searching for.
# audio-chunks\chunk723.wav : Minimum.
# audio-chunks\chunk724.wav : Of a function word.
# audio-chunks\chunk725.wav : Oven open set.
# audio-chunks\chunk726.wav : Infinitely many possible options there.
# audio-chunks\chunk727.wav : Infinitely many possible choices.
# audio-chunks\chunk728.wav : What this is saying is.
# audio-chunks\chunk729.wav : What does serum is saying that well if you want it to look instead of looking over all of them.
# audio-chunks\chunk730.wav : You can actually limit yourself.
# audio-chunks\chunk731.wav : Searching over.
# audio-chunks\chunk732.wav : Ghost voice for which the derivative is equal to.
# audio-chunks\chunk733.wav : Why does it say that.
# audio-chunks\chunk734.wav : It is saying that because this is a necessary condition.
# audio-chunks\chunk735.wav : Any minimum was satisfied.
# Error:
# Error:
# audio-chunks\chunk738.wav : Shopping.
# audio-chunks\chunk739.wav : Over the pool space.
# audio-chunks\chunk740.wav : Feasible region.
# audio-chunks\chunk741.wav : Has become as has been reduced to.
# audio-chunks\chunk742.wav : Watching over.
# audio-chunks\chunk743.wav : Solutions of.
# Error:
# audio-chunks\chunk745.wav : Desi question.
# audio-chunks\chunk746.wav : Solution solution the star of the sea.
# Error:
# audio-chunks\chunk748.wav : Now.
# audio-chunks\chunk749.wav : What are you what kind of equations are these.
# audio-chunks\chunk750.wav : How many variables and how many equation.
# audio-chunks\chunk751.wav : External cell was in aryan.
# audio-chunks\chunk752.wav : And this is the derivative of f with respect to x.
# audio-chunks\chunk753.wav : Any questions in variable.
# audio-chunks\chunk754.wav : Usually the difficulty arises that these equations are not.
# audio-chunks\chunk755.wav : Not necessarily linear so you need.
# audio-chunks\chunk756.wav : Numerical methods.
# audio-chunks\chunk757.wav : What is this still better than having to search.
# audio-chunks\chunk758.wav : Heroine indian x.
# audio-chunks\chunk759.wav : This is how optimisation work you first try to find.
# audio-chunks\chunk760.wav : Mathematical result which constrained your sir.
# audio-chunks\chunk761.wav : Then you come up with an algorithm to go and find search in that particular.
# audio-chunks\chunk762.wav : This is.
# audio-chunks\chunk763.wav : Otherwise there is you know you would have without without a result you will be searching everywhere.
# Error:
# audio-chunks\chunk765.wav : So i want to also.
# audio-chunks\chunk766.wav : This is one consequence that also.
# audio-chunks\chunk767.wav : Some cautionary rma.
# audio-chunks\chunk768.wav : Remember what we say.
# audio-chunks\chunk769.wav : Remember.
# audio-chunks\chunk770.wav : Theorem said that if there is a solution.
# audio-chunks\chunk771.wav : Band smartphone.
# audio-chunks\chunk772.wav : Ok.
# audio-chunks\chunk773.wav : Many different cases and some cases that arise because of this kind of.
# audio-chunks\chunk774.wav : Let's go to all of them.
# audio-chunks\chunk775.wav : The first.
# audio-chunks\chunk776.wav : Sholay train.
# audio-chunks\chunk777.wav : Oscar oasis.
# audio-chunks\chunk778.wav : So let me write this way existence of solution.
# audio-chunks\chunk779.wav : Optimal solution.
# audio-chunks\chunk780.wav : Secondary girls.
# audio-chunks\chunk781.wav : Number of solutions.
# audio-chunks\chunk782.wav : Desi crew.
# audio-chunks\chunk783.wav : Then you have.
# audio-chunks\chunk784.wav : Kaun si kaun.
# audio-chunks\chunk785.wav : Take this case by case.
# audio-chunks\chunk786.wav : Suppose there is an optimal solution.
# audio-chunks\chunk787.wav : If there is an optimal solution then we know that it must satisfy.
# audio-chunks\chunk788.wav : It was satisfied that its derivative is equal to.
# Error:
# audio-chunks\chunk790.wav : Direction of the mysteries and this must be true.
# audio-chunks\chunk791.wav : Now suppose that is only one solution.
# audio-chunks\chunk792.wav : To this bunch of equation.
# audio-chunks\chunk793.wav : Virat is nonlinear equations.
# audio-chunks\chunk794.wav : We know that this is nonlinear equations must this or must be satisfied by the optimal schedule.
# audio-chunks\chunk795.wav : But there may also be.
# audio-chunks\chunk796.wav : Other.
# audio-chunks\chunk797.wav : Other things other points that's all these 9 lena.
# audio-chunks\chunk798.wav : But suppose there is.
# audio-chunks\chunk799.wav : Only one solution.
# audio-chunks\chunk800.wav : Hoodies.
# audio-chunks\chunk801.wav : Nandini.
# audio-chunks\chunk802.wav : Facebook support.
# audio-chunks\chunk803.wav : Only one telugu.
# audio-chunks\chunk804.wav : What does that mean.
# audio-chunks\chunk805.wav : Latest video optimus.
# Error:
# audio-chunks\chunk807.wav : Every optimal solution must satisfy this this set of equation.
# audio-chunks\chunk808.wav : This set of equations have only one cell.
# audio-chunks\chunk809.wav : It has to be done that solution is the ok.
# audio-chunks\chunk810.wav : Ok so then the extra that solve this set of equation.
# audio-chunks\chunk811.wav : Is.
# audio-chunks\chunk812.wav : Is the unique optimal.
# audio-chunks\chunk813.wav : There is.
# audio-chunks\chunk814.wav : A solution.
# audio-chunks\chunk815.wav : Today.
# audio-chunks\chunk816.wav : State of equation.
# audio-chunks\chunk817.wav : To the optimisation problem there is an optimal.
# audio-chunks\chunk818.wav : When you look at these non linear equations.
# audio-chunks\chunk819.wav : You will find more than one point satisfy.
# audio-chunks\chunk820.wav : More than one point.
# audio-chunks\chunk821.wav : Solve this.
# audio-chunks\chunk822.wav : Mujhe man point extra solved.
# audio-chunks\chunk823.wav : More than one point that.
# audio-chunks\chunk824.wav : That causes what does that mean.
# Error:
# audio-chunks\chunk826.wav : It doesn't mean.
# audio-chunks\chunk827.wav : Any of those.
# audio-chunks\chunk828.wav : Any of those could be.
# audio-chunks\chunk829.wav : Good afternoon.
# audio-chunks\chunk830.wav : Nobody nobody kalakand.
# audio-chunks\chunk831.wav : Suppose there is no optimal solution.
# audio-chunks\chunk832.wav : There is no optimal solution.
# audio-chunks\chunk833.wav : And.
# audio-chunks\chunk834.wav : No solution here also.
# audio-chunks\chunk835.wav : Then then again nothing can be said.
# audio-chunks\chunk836.wav : Suppose there is.
# audio-chunks\chunk837.wav : Again.
# audio-chunks\chunk838.wav : Suppose there is no optimal solution.
# audio-chunks\chunk839.wav : But there is a unique point at which you can solve.
# audio-chunks\chunk840.wav : The system of equation.
# audio-chunks\chunk841.wav : What can one conclude about this.
# audio-chunks\chunk842.wav : Again we can't say anything.
# audio-chunks\chunk843.wav : Remember because the theorem started with the premise that.
# audio-chunks\chunk844.wav : You have a solution.
# audio-chunks\chunk845.wav : There is no solution the theorem will not tell you anything.
# audio-chunks\chunk846.wav : And again once again there is no.
# audio-chunks\chunk847.wav : No optimal solution and then there is.
# audio-chunks\chunk848.wav : More than one.
# audio-chunks\chunk849.wav : More than one solution.
# audio-chunks\chunk850.wav : Today.
# audio-chunks\chunk851.wav : That also does not say.
# audio-chunks\chunk852.wav : I will.
# audio-chunks\chunk853.wav : Lakshmi.
# audio-chunks\chunk854.wav : Let me illustrate this for.
# audio-chunks\chunk855.wav : For you.
# audio-chunks\chunk856.wav : Rustom example.
# audio-chunks\chunk857.wav : Let's do the first kiss first.
# audio-chunks\chunk858.wav : Bus cases when there is an optimal solution and that is a unique.
# audio-chunks\chunk859.wav : Unique solution.
# audio-chunks\chunk860.wav : What are you doing i will take us to be se -1 to 1 the open interval -1 to 1.
# audio-chunks\chunk861.wav : Endless summer.
# audio-chunks\chunk862.wav : Functions illustrating this.
# Error:
# audio-chunks\chunk864.wav : 1.
# audio-chunks\chunk865.wav : 1.
# audio-chunks\chunk866.wav : I am minimising this reserve.
# audio-chunks\chunk867.wav : Find that there is a unique point like this.
# audio-chunks\chunk868.wav : Where.
# audio-chunks\chunk869.wav : The derivative has become equal.
# audio-chunks\chunk870.wav : Then it has to be that this is also the.
# Error:
# audio-chunks\chunk872.wav : This is happy ke.
# audio-chunks\chunk873.wav : S p s.
# audio-chunks\chunk874.wav : Once again i am on -121.
# audio-chunks\chunk875.wav : Brijesh.
# audio-chunks\chunk876.wav : And.
# audio-chunks\chunk877.wav : I get i have a function that look like this.
# audio-chunks\chunk878.wav : Now if you look at the derivative of this function.
# audio-chunks\chunk879.wav : Which of the function has become zero here.
# audio-chunks\chunk880.wav : Nepal to become zero here.
# audio-chunks\chunk881.wav : There are no more no more than one point.
# audio-chunks\chunk882.wav : Weather derivative as vanish.
# audio-chunks\chunk883.wav : We need to dig deeper.
# audio-chunks\chunk884.wav : In order to conclude what we offer.
# audio-chunks\chunk885.wav : In this case we have to dig deeper than that so that you have provided does not can help us including.
# audio-chunks\chunk886.wav : What was case we look like.
# audio-chunks\chunk887.wav : No optimal solution and no derivative also does not marry.
# audio-chunks\chunk888.wav : Good night pic.
# audio-chunks\chunk889.wav : Sudesh take for visa tracking.
# audio-chunks\chunk890.wav : I want to keep the domain is -1 to 1.
# audio-chunks\chunk891.wav : August 1 riyal.
# audio-chunks\chunk892.wav : Distance.
# audio-chunks\chunk893.wav : Line lag.
# audio-chunks\chunk894.wav : Where is there is there is no optimal solution the infimum is not attended.
# audio-chunks\chunk895.wav : It would have been attained at -1 if -1 was part of.
# audio-chunks\chunk896.wav : Dadi aur daman is open.
# Error:
# audio-chunks\chunk898.wav : Not attend.
# audio-chunks\chunk899.wav : And also that function tape is such that its derivative.
# audio-chunks\chunk900.wav : Does not balance.
# audio-chunks\chunk901.wav : Katpur.
# audio-chunks\chunk902.wav : Orange.
# audio-chunks\chunk903.wav : Aur.
# audio-chunks\chunk904.wav : Battery case.
# Error:
# audio-chunks\chunk906.wav : Tricky because.
# audio-chunks\chunk907.wav : Your you have a unique solution to the to the equation the derivative is equal to zero.
# audio-chunks\chunk908.wav : But.
# audio-chunks\chunk909.wav : There is no guarantee that the optimal solution actually does not.
# audio-chunks\chunk910.wav : What is outlook.
# Error:
# audio-chunks\chunk912.wav : Justin what this figure 1.
# audio-chunks\chunk913.wav : Define what does figure 1.
# audio-chunks\chunk914.wav : Represent this.
# audio-chunks\chunk915.wav : Ok this sort of.
# audio-chunks\chunk916.wav : Where is more since there is no.
# audio-chunks\chunk917.wav : Bp mum is not attend.
# audio-chunks\chunk918.wav : But there is this point here.
# audio-chunks\chunk919.wav : Weather derivative ashwini.
# Error:
# Error:
# audio-chunks\chunk922.wav : Is 4 is often responsible for many errors because.
# audio-chunks\chunk923.wav : Code checking the solution exist people jump into checking.
# audio-chunks\chunk924.wav : Solutions of.
# audio-chunks\chunk925.wav : Derivative equal to zero.
# audio-chunks\chunk926.wav : Open come up with.
# audio-chunks\chunk927.wav : Answer that are not.
# audio-chunks\chunk928.wav : Solutions of the.
# audio-chunks\chunk929.wav : Optimal solution.
# audio-chunks\chunk930.wav : London.
# audio-chunks\chunk931.wav : 5 would look.
# audio-chunks\chunk932.wav : Say something like this.
# audio-chunks\chunk933.wav : -1.
# audio-chunks\chunk934.wav : Again.
# audio-chunks\chunk935.wav : Multiple point.
# audio-chunks\chunk936.wav : Weather derivative is vanishing.
# audio-chunks\chunk937.wav : There is no solution.
# Error:
# audio-chunks\chunk939.wav : Harishchandra natak.
# audio-chunks\chunk940.wav : Illustrate.
# audio-chunks\chunk941.wav : Now let me come to the point.
# audio-chunks\chunk942.wav : That one of yours.
# audio-chunks\chunk943.wav : What about existence now.
# audio-chunks\chunk944.wav : Remember biscuit tera existence under what condition.
# audio-chunks\chunk945.wav : Objective function has to be continuous.
# audio-chunks\chunk946.wav : And feasible region has to be closed and bounded.
# audio-chunks\chunk947.wav : Feasible region that open.
# audio-chunks\chunk948.wav : Not closed then is we could be bounded but it's not necessarily.
# audio-chunks\chunk949.wav : Ok to dehradun train set that both closed and open.
# audio-chunks\chunk950.wav : Border border.
# audio-chunks\chunk951.wav : Isliye is no guarantee of close being close.
# audio-chunks\chunk952.wav : Surendra for you need another.
# audio-chunks\chunk953.wav : Independent way of verifying that the solution actually exist.
# ...
# audio-chunks\chunk1049.wav : Of the function near that one.
# audio-chunks\chunk1050.wav : If you also have second derivative information.
# audio-chunks\chunk1051.wav : Can you can actually construct a quadratic approx.
# audio-chunks\chunk1052.wav : Ok so that that's.
# audio-chunks\chunk1053.wav : Karan that we will use to by taylor's theorem.
# audio-chunks\chunk1054.wav : Tere tere hd me like that.
# audio-chunks\chunk1055.wav : Your pic star plus.
# audio-chunks\chunk1056.wav : Delta h.
# audio-chunks\chunk1057.wav : Is equal to f of x 6.
# audio-chunks\chunk1058.wav : Plus.
# Error:
# audio-chunks\chunk1060.wav : Fx star plus.
# audio-chunks\chunk1061.wav : Effect.
# audio-chunks\chunk1062.wav : Plus.
# audio-chunks\chunk1063.wav : Aap.
# audio-chunks\chunk1064.wav : Delta square.
# audio-chunks\chunk1065.wav : Hr transport.
# audio-chunks\chunk1066.wav : News.
# audio-chunks\chunk1067.wav : Consistent with one kind of motivation.
# audio-chunks\chunk1068.wav : Lucknow.
# audio-chunks\chunk1069.wav : Quantity the recipe all quantities.
# audio-chunks\chunk1070.wav : Dot.com.
# audio-chunks\chunk1071.wav : Is now small of delta square.
# audio-chunks\chunk1072.wav : 2nd puc political process.
# audio-chunks\chunk1073.wav : And quantity that.
# audio-chunks\chunk1074.wav : The residual error that remains after that quadratic approximation.
# audio-chunks\chunk1075.wav : Small of data square what is mean this.
# audio-chunks\chunk1076.wav : This is now a function that after dividing by delta square also.
# audio-chunks\chunk1077.wav : Satta.com.
# Error:
# audio-chunks\chunk1079.wav : But now i remember this.
# audio-chunks\chunk1080.wav : Because if is extra is a local minimum.
# audio-chunks\chunk1081.wav : This gradient hair is equal to zero.
# audio-chunks\chunk1082.wav : This first time is gone.
# audio-chunks\chunk1083.wav : So you are left with just a perfect star.
# audio-chunks\chunk1084.wav : Plus aap.
# audio-chunks\chunk1085.wav : Delta square.
# audio-chunks\chunk1086.wav : H transpose.
# audio-chunks\chunk1087.wav : Square fat.
# audio-chunks\chunk1088.wav : Star apps.
# audio-chunks\chunk1089.wav : Plus.
# audio-chunks\chunk1090.wav : Mall of qatar.
# audio-chunks\chunk1091.wav : Now once again we have.
# audio-chunks\chunk1092.wav : In a small neighborhood.
# audio-chunks\chunk1093.wav : F of x star plus delta h.
# audio-chunks\chunk1094.wav : Will be late will be greater than equal to a perfect sir.
# audio-chunks\chunk1095.wav : Super delta small enough.
# audio-chunks\chunk1096.wav : What this.
# audio-chunks\chunk1097.wav : This implies that.
# audio-chunks\chunk1098.wav : You have.
# audio-chunks\chunk1099.wav : Half.
# audio-chunks\chunk1100.wav : Delta square.
# audio-chunks\chunk1101.wav : H transpose.
# audio-chunks\chunk1102.wav : Delta positive and.
# audio-chunks\chunk1103.wav : Reliance mall inox.
# audio-chunks\chunk1104.wav : What that means.
# audio-chunks\chunk1105.wav : You can you can advise what by you can divide by delta and then let delta go 20.
# Error:
# audio-chunks\chunk1107.wav : Hr transport.
# audio-chunks\chunk1108.wav : Greater than equal to.
# audio-chunks\chunk1109.wav : This must be true for.
# audio-chunks\chunk1110.wav : Did you get this condition is transpose.
# audio-chunks\chunk1111.wav : Asian of hf at extra time.
# audio-chunks\chunk1112.wav : Should be greater than equal to zero.
# audio-chunks\chunk1113.wav : Weather condition this to be true.
# audio-chunks\chunk1114.wav : This is true for all.
# audio-chunks\chunk1115.wav : Upar wale.
# audio-chunks\chunk1116.wav : Hindi super college this just.
# audio-chunks\chunk1117.wav : Abe tricks like this matrix.
# audio-chunks\chunk1118.wav : Like this that satisfies.
# audio-chunks\chunk1119.wav : This kind of inequality.
# audio-chunks\chunk1120.wav : Matrix.
# audio-chunks\chunk1121.wav : Of this kind which satisfies.
# audio-chunks\chunk1122.wav : Anil quality like this for all.
# audio-chunks\chunk1123.wav : College.
# audio-chunks\chunk1124.wav : Sort of matrix is called positive semidefinite.
# audio-chunks\chunk1125.wav : Define.
# audio-chunks\chunk1126.wav : Define that for user.
# Error:
# audio-chunks\chunk1128.wav : Set.
# audio-chunks\chunk1129.wav : Positive.
# audio-chunks\chunk1130.wav : Semidefinite.
# audio-chunks\chunk1131.wav : V transport.
# audio-chunks\chunk1132.wav : Movie.
# audio-chunks\chunk1133.wav : Greater than equal to zero.
# audio-chunks\chunk1134.wav : Call veena.
# audio-chunks\chunk1135.wav : So.
# audio-chunks\chunk1136.wav : Vidyut.
# audio-chunks\chunk1137.wav : With this definition what we ask what we get is that.
# audio-chunks\chunk1138.wav : Look at this hessian matrix evaluated at ekta.
# audio-chunks\chunk1139.wav : Must be.
# audio-chunks\chunk1140.wav : Positive seminar.
# audio-chunks\chunk1141.wav : Christmas be positive.
# audio-chunks\chunk1142.wav : If your.
# audio-chunks\chunk1143.wav : F is.
# audio-chunks\chunk1144.wav : Y is differentiable.
# audio-chunks\chunk1145.wav : We can say more we can say that.
# audio-chunks\chunk1146.wav : If you are ekta is a local minimum not only much the derivative equal to zero.
# audio-chunks\chunk1147.wav : Among the points where the derivative is equal to zero you for the cheque.
# audio-chunks\chunk1148.wav : You can for the narrow down.
# audio-chunks\chunk1149.wav : Table.
# audio-chunks\chunk1150.wav : Karate points where.
# audio-chunks\chunk1151.wav : Bastion is positive definite.
# audio-chunks\chunk1152.wav : Then i want.
# Error:
# audio-chunks\chunk1154.wav : 2000 your optimal solutions must be amongst.
# audio-chunks\chunk1155.wav : This is now in history.
# audio-chunks\chunk1156.wav : What about efficiency sufficiency means what.
# audio-chunks\chunk1157.wav : Necessary means simply that 16 solution this is a condition that.
# audio-chunks\chunk1158.wav : The solution was added.
# audio-chunks\chunk1159.wav : Sufficiency means the other vera.
# Error:
# audio-chunks\chunk1161.wav : Efficiency means the other way around here is a condition if i get if i can verify.
# audio-chunks\chunk1162.wav : Then definitely that's.
# audio-chunks\chunk1163.wav : Now.
# audio-chunks\chunk1164.wav : How was what would be a sufficient condition in this case.
# audio-chunks\chunk1165.wav : Sufficient conditions are stronger than necessary.
# audio-chunks\chunk1166.wav : Because the patient condition road in flight.
# audio-chunks\chunk1167.wav : What will what would be.
# audio-chunks\chunk1168.wav : What would be the sufficient condition.
# audio-chunks\chunk1169.wav : Rakesh.
# audio-chunks\chunk1170.wav : You must have the derivative is equal to that is that that that such that is necessary.
# audio-chunks\chunk1171.wav : Bus also.
# audio-chunks\chunk1172.wav : And but in addition to this there is the second derivative being.
# audio-chunks\chunk1173.wav : Arbi husain being positive semidefinite.
# audio-chunks\chunk1174.wav : If you ask for something more.
# audio-chunks\chunk1175.wav : Yaar beli.
# audio-chunks\chunk1176.wav : Baby hasini.
# audio-chunks\chunk1177.wav : Weakly positive definite.
# audio-chunks\chunk1178.wav : Positive definite.
# audio-chunks\chunk1179.wav : Then that ensures that this.
# audio-chunks\chunk1180.wav : The director is a local.
# audio-chunks\chunk1181.wav : So.
# audio-chunks\chunk1182.wav : Sufficient condition.
# audio-chunks\chunk1183.wav : It is positive definite.
# audio-chunks\chunk1184.wav : What does that mean.
# audio-chunks\chunk1185.wav : That means that.
# audio-chunks\chunk1186.wav : V transport.
# audio-chunks\chunk1187.wav : 10 square feet.
# Error:
# audio-chunks\chunk1189.wav : Taraweeh.
# audio-chunks\chunk1190.wav : This is positive.
# audio-chunks\chunk1191.wav : For all we that are not zero.
# audio-chunks\chunk1192.wav : If you have your.
# audio-chunks\chunk1193.wav : Next hour.
# audio-chunks\chunk1194.wav : Nice such that the derivative is equal to zero.
# audio-chunks\chunk1195.wav : And the.
# audio-chunks\chunk1196.wav : Hessian is positive definite that means we transfers the halcyon times we again.
# audio-chunks\chunk1197.wav : Strictly positive for all b not equal to zero.
# audio-chunks\chunk1198.wav : Then the text is a.
# audio-chunks\chunk1199.wav : Show the optimisation over open sets is that.
# audio-chunks\chunk1200.wav : Does not always not a very common problem that occur.
# Error:
# audio-chunks\chunk1202.wav : The kind of.
# audio-chunks\chunk1203.wav : When one writes.
# audio-chunks\chunk1204.wav : And optimisation problem like this your writing a minimization of a function f.
# audio-chunks\chunk1205.wav : Subject to.
# audio-chunks\chunk1206.wav : Sabjiyon pics.
# audio-chunks\chunk1207.wav : Nasbandi equal to zero and h of x.
# audio-chunks\chunk1208.wav : 20.
# audio-chunks\chunk1209.wav : The less than equal to zero and educate equal to zero this kind of constraints.
# audio-chunks\chunk1210.wav : Is functions g and h are continuous.
# audio-chunks\chunk1211.wav : These constraints ensure that your site is actually close.
# audio-chunks\chunk1212.wav : Bp double vision.
# audio-chunks\chunk1213.wav : But.
# audio-chunks\chunk1214.wav : This.
# audio-chunks\chunk1215.wav : Closed.
# audio-chunks\chunk1216.wav : Zika virus.
# audio-chunks\chunk1217.wav : Class of problems where it's very important to consider.
# audio-chunks\chunk1218.wav : Baby hi baby naturally encounter open set.
# audio-chunks\chunk1219.wav : Adoor weather on open.
# audio-chunks\chunk1220.wav : Sabhi problem of minimising effect.
# Error:
# audio-chunks\chunk1222.wav : Just.
# audio-chunks\chunk1223.wav : Is in orion mall.
# Error:
# audio-chunks\chunk1225.wav : This is what called unconstrained minimizer.
# audio-chunks\chunk1226.wav : Unconstrained minimization.
# audio-chunks\chunk1227.wav : This.
# audio-chunks\chunk1228.wav : This is actually a minimization over an open set because.
# audio-chunks\chunk1229.wav : Are itself is an open.
# Error:
# audio-chunks\chunk1231.wav : On the previous results that i just mentioned a all apply to minimization over and over.
# audio-chunks\chunk1232.wav : Aur over.
# audio-chunks\chunk1233.wav : Ovary nankan foreign minimization of in unconstrained.
# Error:
# audio-chunks\chunk1235.wav : Unconstrained meaning.
# Error:
# audio-chunks\chunk1237.wav : You can add another point to note is that suppose you had installed maximization.
# audio-chunks\chunk1238.wav : Instead of minimization.
# audio-chunks\chunk1239.wav : About the results day.
# audio-chunks\chunk1240.wav : Yes so what would my your conclusions change.
# audio-chunks\chunk1241.wav : Extrusion.
# audio-chunks\chunk1242.wav : The conclusion of of.
# Error:
# audio-chunks\chunk1244.wav : Office 13 here.
# audio-chunks\chunk1245.wav : Whether derivative is equal to zero this contribution will continue to work.
# audio-chunks\chunk1246.wav : Even if you have a maximum.
# audio-chunks\chunk1247.wav : Garbhvati.
# Error:
# audio-chunks\chunk1249.wav : Has to be zero.
# audio-chunks\chunk1250.wav : The conclusion of.
# audio-chunks\chunk1251.wav : Office decorum.
# audio-chunks\chunk1252.wav : This conclusion year.
# audio-chunks\chunk1253.wav : Red light.
# audio-chunks\chunk1254.wav : This.
# audio-chunks\chunk1255.wav : Blue line.
# audio-chunks\chunk1256.wav : That behaviour must be positive semidefinite.
# audio-chunks\chunk1257.wav : Seems to be positive semidefinite that gets changed to hasten should be negative samet.
# audio-chunks\chunk1258.wav : And sufficient condition will change to.
# audio-chunks\chunk1259.wav : Hasin should be next.
# audio-chunks\chunk1260.wav : Positive definite.
# audio-chunks\chunk1261.wav : Negative.
# audio-chunks\chunk1262.wav : Negative definite simply means that in place of.
# audio-chunks\chunk1263.wav : Please semidefinite would just switch this inequality to a less than equal to.
# audio-chunks\chunk1264.wav : And this inequality also.
# audio-chunks\chunk1265.wav : Takle lakkha.
# audio-chunks\chunk1266.wav : I am asking about this details can.
# audio-chunks\chunk1267.wav : Is it workout.
# audio-chunks\chunk1268.wav : Sauvie island.
# "I will begin with the earth. Study of first class of optimization problems which is. Optimisation. A function. Over. An open set. So. What this means is that the. Feasible region. Open sex. And. Function. Aur. Photo function. Kylie. Jaipur. Function. You love you know this to be. Differentiable function. Now. Going to talk about differentiable functions i need to tell you a little bit about. Bhai notation for derivatives second derivatives install. Let s be a function. From. R and 2r. Nxn aryan. I will write it. I will be not it in the sort of way. Co-ordinate size. This is the. Every vector x narayan this we will be referring to fitted as a column vector. Now. When i write something like s x. Valuated at exide. What this means is this is me. Derivative. Office. At. Exact. Smallest year. Smallest in this notation this simply said that. Derivative with respect to x. Bittu. This should be important when we are talking about. Functions that are functions of more than one way. We may want to take derivative only with recipe. Derivative. Another notation for the same thing. Is. Value added tax. Aur. Important thing to note is that this. This quantity app. Xx. This is actually a role actor. Google. It is defined in this way you can consider the partial derivatives. With respect to each of the components of x. Daman to erode. Evaluate all of these attic. Sof subex evaluated at expert is this row vector. There is a related quantity. Denoted in this sort of way. Aur. To be more explicit about. What's your differentiating with. This way and that is simply. The transpose of this perimeter. This thing is called. The gradient. Offer. Attack. Once again the. Small express. Simply do not. That. Gradient with respect to the variable. Propose. You have a function f which is. Function from. Aryan. Cross rm. You are. My very well. Bi variable x. X variable live. Aryan. Why variable is in array. Dainik bhai write something like this f sub x. Write something like this left cervix. At. White korma white. This year. In this row vector or column vector. It is a robot. Ok. Abhi to how many components. And company. Because that is the number of component and taking the derivative with. Accident. Zero vector. Also denoted by. Now if. F is. Both of these cases here in this case as well as in. Dalia case. Go to biscuits. F was a function that map to our. The sof. Itself did not have. Multiple. Rajasv incomp. F is a scalar valued. Wooden now if f is better value. Write the square. Inner value. S. A vector valued function then say we have. Suppose f is a function from r in. Rustom rm. And. What we will do if we will think of this. Every. Output of this vector. Every point in the. Image of this of f is itself a vector. Call ambedkar. F. Be part of like this if. Atta point. X. Is equal to. This kind of column vector. F1 of x. F2 effect. Gov.in. I'm calling. If i want to do if i take the derivative of x with respect to x. What i need to do is. 1 the derivative of each of these component. This. Evaluated at. Now become. Every row. Every every component of f. Will have a derivative and will its derivative would be a row vector like this. And what you are going to get now is row vector stop that one below the other so the. Pradesh. Ko dikhao. So that's your. This is also good. Multiple name for this. Simple. Call derivative. Aap f. At at. Other name for it is that it. Alter jacobian. Ok. Hi tech. How we can also write hai. Another higher order derivative. What's called. Asian. Asian is simply. Profile pic. Of the derivative. But the derivative of the day. I need to take. I am taking the derivative of the derivative. Nothing. Select. I am taking the derivative. Of the gradient. Evaluating that. This. Another term for the same. Another way of writing the same thing. This again. Because the gradient is a column vector. Pick the derivative of that. Anda. Then we'll go. Agnimitra. Matrix that look. Aur didi valuated natak. Another notation for the same thing is simpl ...

# %%
# importing libraries 
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# %%
# import os; print(os.environ["PATH"].split(os.pathsep))
